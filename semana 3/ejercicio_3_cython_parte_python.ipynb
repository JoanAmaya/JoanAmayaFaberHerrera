# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
txt= np.loadtxt("Mis datos.txt")
x=np.zeros(len(txt))
y=np.zeros(len(txt))

# %%
for i in range(len(txt)):
    x[i],y[i]=txt[i][0],txt[i][1]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y,label="derivada central")
plt.legend()
plt.savefig("derivada_central_cython")
